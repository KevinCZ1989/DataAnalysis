# %% [markdown]
# <img SRC="img01.jpeg"/>

# %% [markdown]
# <center><h1 Style="color:#8FBC8F"> Analisis de datos </h1></center>
# <center><h5>Universidad Castro Carazo </h5></center>
# <center><h6> 3C - 2022 </h6></center>
# </br>
# <p Style = "text-align: justify">Este notebook contiene el analisis de los datos de los vehiculos a la venta por parte de la empresa Pk2, esta empresa se encuentra interesada en responder una pregunta de negocio particular.
#
# ¿Cómo se puede incrementar las ventas de autos de segunda mano?
#
# Para esto se realiza un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las ditribuciones de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos, esto para dotar de insumos suficientes a la toma de desiciones.</p>
# </br>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile"> Fuente de Datos para el proceso de analisis </a>

# %% [markdown]
# <h2 Style="color:#1E90FF">1. Carga y estandarizacion de los set de datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>
#     <li>Importar las librerias de necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los ecabezados de los DataFrames</li>
#     <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>
#
# <h3 Style="color:#2F4F4F">1.1 Importar las librerias</h3>

# %%
import pandas as pd       #Se usa para el manejo de los DataFrame
import numpy as np        #Se usa para el manejo de las estructuras de datos (Array, Listas, Tuplas, Diccionarios)
import matplotlib.pyplot as plt #Se usa para crear las graficas.

# %% [markdown]
# <h3 Style="color:#2F4F4F">1.2 Importar los Set de Datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors", 
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

# df = Data Frame
df_1er_autos = pd.read_csv("autos.csv", names=cols)
df_2do_autos = pd.read_csv("Autos1.csv", names=cols)

# %%
df_1er_autos.shape
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
df_1er_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [5 rows x 26 columns]

# %%
df_2do_autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# 0  4800   24      30   9639
# 1  4800   24      30   9989
# 2  4800   24      30  11199
# 3  4800   24      30  11549
# 4  4800   24      30  17669
#
# [5 rows x 26 columns]

# %%
df_2do_autos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0          ?  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 24  front  100.4  ...           97     idi  3.01    3.40        23.0
# 25  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 26  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City  Higway  price
# 24         68  4500   33      38  13845
# 25         88  5500   25      31  12290
# 26        114  5400   23      28  12940
# 27        114  5400   23      28  13415
# 28        114  5400   24      28  15985
#
# [5 rows x 26 columns]

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# 25%    2140.000000    97.000000     8.600000   19.000000   25.000000
# 50%    2405.000000   110.000000     9.000000   25.000000   30.000000
# 75%    2844.000000   141.000000     9.400000   30.000000   36.000000
# max    4066.000000   326.000000    23.000000   49.000000   54.000000

# %% [markdown]
# <h5 Style= "color #B0CSDE"> 1.3. Revisar los encabezados de los data frame </h5>
# <p> Se motiva la estandarización de los nombres de las columnas, considerando lo siguiente </p>
#
# <ol>
#         <li> Los nombres de las columnas no deben contener espacios en blanco </li>
#         <li> Los nombres no deben empezar por números </li>
#         <li> Si el nombre se conforma por 2 o más palabras, la letra inicial de cada palabra va en mayúscula </li>
#         <li> No deben existir nombres reprtidos </li>
# </ol>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename({"engine-size" : "Engine Size"}, axis=1, inplace=True)
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'Engine Size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename({"compression" : "Compression"}, axis=1, inplace=True)
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  Engine Size  Compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# 25%    2140.000000    97.000000     8.600000   19.000000   25.000000
# 50%    2405.000000   110.000000     9.000000   25.000000   30.000000
# 75%    2844.000000   141.000000     9.400000   30.000000   36.000000
# max    4066.000000   326.000000    23.000000   49.000000   54.000000

# %%
df_2do_autos.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  29.000000   29.000000   29.000000  29.000000  29.000000    29.000000
# mean    0.827586  100.103448  177.186207  66.134483  54.406897  2580.000000
# std     1.691765    3.082726    7.178327   0.917012   1.666676   310.887325
# min    -2.000000   94.500000  159.300000  64.000000  51.400000  2209.000000
# 25%    -1.000000   97.300000  171.700000  65.500000  53.000000  2300.000000
# 50%     2.000000  100.400000  176.200000  66.500000  54.900000  2536.000000
# 75%     2.000000  102.400000  183.100000  66.900000  55.700000  2912.000000
# max     3.000000  104.500000  188.800000  67.700000  57.500000  3151.000000
#
#        engine-size       bore     stroke  compression  horsepower  \
# count    29.000000  29.000000  29.000000    29.000000   29.000000
# mean    128.000000   3.330690   3.402069    11.475862  102.413793
# std      23.653752   0.240088   0.108278     5.318610   29.382353
# min      97.000000   3.010000   3.150000     8.500000   52.000000
# 25%     109.000000   3.190000   3.350000     9.000000   85.000000
# 50%     122.000000   3.270000   3.400000     9.300000   92.000000
# 75%     146.000000   3.620000   3.500000     9.500000  116.000000
# max     171.000000   3.780000   3.540000    23.000000  161.000000
#
#               peak       City     Higway         price
# count    29.000000  29.000000  29.000000     29.000000
# mean   4970.689655  25.896552  31.448276  11692.793103
# std     448.910833   5.045117   5.803855   2906.059106
# min    4200.000000  19.000000  24.000000   7775.000000
# 25%    4800.000000  24.000000  28.000000   9639.000000
# 50%    5200.000000  24.000000  30.000000  11199.000000
# 75%    5400.000000  27.000000  34.000000  13415.000000
# max    5500.000000  37.000000  46.000000  17669.000000

# %%
df_1er_autos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2          ?         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1          ?         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0          ?         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  Engine Size  system  bore  stroke Compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front   94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front   99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front   99.4  ...          136    mpfi  3.19    3.40         8.0
# 5    fwd  front   99.8  ...          136    mpfi  3.19    3.40         8.5
# 6    fwd  front  105.8  ...          136    mpfi  3.19    3.40         8.5
# 7    fwd  front  105.8  ...          136    mpfi  3.19    3.40         8.5
# 8    fwd  front  105.8  ...          131    mpfi  3.13    3.40         8.3
# 9    4wd  front   99.5  ...          131    mpfi  3.13    3.40         7.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
# 5        110  5500   19     25  15250
# 6        110  5500   19     25  17710
# 7        110  5500   19     25  18920
# 8        140  5500   17     20  23875
# 9        160  5500   16     22      ?
#
# [10 rows x 26 columns]

# %%
temp = df_1er_autos.groupby(["make"]).count()
temp = temp.iloc[:,:1]
temp
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   7
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  4
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                5
# renault                2
# saab                   6
# subaru                12
# toyota                32
# volkswagen            12
# volvo                  3

# %%
unionArchivos = [df_1er_autos, df_2do_autos]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 28)

# %% [markdown]
# <h2 style='color:#00008B'> 2. Manejo de los valores faltantes o perdidos </h2>
# <p> ¿Qué se hace en este apartado?</p>
#
# <ol>
#     <li> Identificar cómo se muestran los valores faltantes y los estandarizamos. (NaN)</li>
#     <li> Contar la cantidad de valores faltantes por variable.</li>
#     <li> Análisis de imputación de valores números con la media.</li>
#     <li> Análisis de imputación de valores categóricos con el más frecuente.</li>
#     <li> Eliminar filas con valores faltantes.</li>
# </ol>
#
# <h2 style='color:#00008B'> 2.1 Identificar como se muestran los valores faltantes y los estandarizamos (NaN) </h2>

# %%
dfAutos
# Out:
#     symboling normalized         make    fuel aspiration doors        style  \
# 0           3          ?  alfa-romero     gas        std   two  convertible
# 1           3          ?  alfa-romero     gas        std   two  convertible
# 2           1          ?  alfa-romero     gas        std   two    hatchback
# 3           2        164         audi     gas        std  four        sedan
# 4           2        164         audi     gas        std  four        sedan
# ..        ...        ...          ...     ...        ...   ...          ...
# 24          0          ?   volkswagen  diesel      turbo  four        sedan
# 25          0          ?   volkswagen     gas        std  four        wagon
# 26         -2        103        volvo     gas        std  four        sedan
# 27         -1         74        volvo     gas        std  four        wagon
# 28         -2        103        volvo     gas        std  four        sedan
#
#    wheels engine   base  ...  bore  stroke  Compression  horsepower  peak  \
# 0     rwd  front   88.6  ...  3.47    2.68          9.0         111  5000
# 1     rwd  front   88.6  ...  3.47    2.68          9.0         111  5000
# 2     rwd  front   94.5  ...  2.68    3.47          9.0         154  5000
# 3     fwd  front   99.8  ...  3.19    3.40         10.0         102  5500
# 4     4wd  front   99.4  ...  3.19    3.40          8.0         115  5500
# ..    ...    ...    ...  ...   ...     ...          ...         ...   ...
# 24    fwd  front  100.4  ...  3.01     3.4          NaN          68  4500
# 25    fwd  front  100.4  ...  3.19     3.4          NaN          88  5500
# 26    rwd  front  104.3  ...  3.78    3.15          NaN         114  5400
# 27    rwd  front  104.3  ...  3.78    3.15          NaN         114  5400
# 28    rwd  front  104.3  ...  3.78    3.15          NaN         114  5400
#
#    City  Higway  price engine-size compression
# 0    21      27  13495         NaN         NaN
# 1    21      27  16500         NaN         NaN
# 2    19      26  16500         NaN         NaN
# 3    24      30  13950         NaN         NaN
# 4    18      22  17450         NaN         NaN
# ..  ...     ...    ...         ...         ...
# 24   33      38  13845        97.0        23.0
# 25   25      31  12290       109.0         9.0
# 26   23      28  12940       141.0         9.5
# 27   23      28  13415       141.0         9.5
# 28   24      28  15985       141.0         9.5
#
# [226 rows x 28 columns]

# %%
dfAutos.replace("?", np.nan, inplace=True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price engine-size compression
# 0      27  13495         NaN         NaN
# 1      27  16500         NaN         NaN
# 2      26  16500         NaN         NaN
# 3      30  13950         NaN         NaN
# 4      22  17450         NaN         NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#20B2AA"> 2.2 Contar la cantidad de valores faltantes por variable. </h2>

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False        True  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False        True  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...   bore  stroke  Compression  horsepower   peak   City  \
# 0   False  False  ...  False   False        False       False  False  False
# 1   False  False  ...  False   False        False       False  False  False
# 2   False  False  ...  False   False        False       False  False  False
# 3   False  False  ...  False   False        False       False  False  False
# 4   False  False  ...  False   False        False       False  False  False
# 5   False  False  ...  False   False        False       False  False  False
# 6   False  False  ...  False   False        False       False  False  False
# 7   False  False  ...  False   False        False       False  False  False
# 8   False  False  ...  False   False        False       False  False  False
# 9   False  False  ...  False   False        False       False  False  False
#
#    Higway  price  engine-size  compression
# 0   False  False         True         True
# 1   False  False         True         True
# 2   False  False         True         True
# 3   False  False         True         True
# 4   False  False         True         True
# 5   False  False         True         True
# 6   False  False         True         True
# 7   False  False         True         True
# 8   False  False         True         True
# 9   False   True         True         True
#
# [10 rows x 28 columns]

# %%
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# Engine Size
# False    197
# True      29
# Name: Engine Size, dtype: int64
#
# system
# False    226
# Name: system, dtype: int64
#
# bore
# False    222
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    222
# True       4
# Name: stroke, dtype: int64
#
# Compression
# False    197
# True      29
# Name: Compression, dtype: int64
#
# horsepower
# False    224
# True       2
# Name: horsepower, dtype: int64
#
# peak
# False    224
# True       2
# Name: peak, dtype: int64
#
# City
# False    226
# Name: City, dtype: int64
#
# Higway
# False    226
# Name: Higway, dtype: int64
#
# price
# False    222
# True       4
# Name: price, dtype: int64
#
# engine-size
# True     197
# False     29
# Name: engine-size, dtype: int64
#
# compression
# True     197
# False     29
# Name: compression, dtype: int64

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  226.000000  226.000000  226.000000  226.000000  226.000000
# mean     0.902655   98.626991  173.929646   65.853982   53.728761
# std      1.271672    5.611570   11.744470    2.015475    2.365420
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.300000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  101.800000  180.200000   66.500000   55.600000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  Engine Size  Compression        City      Higway  \
# count   226.000000   197.000000   197.000000  226.000000  226.000000
# mean   2540.597345   126.263959    10.128020   25.477876   31.044248
# std     498.165891    42.282594     3.934467    6.384143    6.767096
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# 25%    2205.250000    97.000000     8.600000   20.000000   25.000000
# 50%    2414.000000   110.000000     9.000000   25.000000   30.000000
# 75%    2846.250000   141.000000     9.400000   30.000000   34.000000
# max    4066.000000   326.000000    23.000000   49.000000   54.000000
#
#        engine-size  compression
# count    29.000000    29.000000
# mean    128.000000    11.475862
# std      23.653752     5.318610
# min      97.000000     8.500000
# 25%     109.000000     9.000000
# 50%     122.000000     9.300000
# 75%     146.000000     9.500000
# max     171.000000    23.000000

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
#
#    Higway  price engine-size compression
# 0      27  13495         NaN         NaN
# 1      27  16500         NaN         NaN
# 2      26  16500         NaN         NaN
#
# [3 rows x 28 columns]

# %%
dfAutos.tail(3)
# Out:
#     symboling normalized   make fuel aspiration doors  style wheels engine  \
# 26         -2        103  volvo  gas        std  four  sedan    rwd  front
# 27         -1         74  volvo  gas        std  four  wagon    rwd  front
# 28         -2        103  volvo  gas        std  four  sedan    rwd  front
#
#      base  ...  bore  stroke  Compression  horsepower  peak City  Higway  \
# 26  104.3  ...  3.78    3.15          NaN         114  5400   23      28
# 27  104.3  ...  3.78    3.15          NaN         114  5400   23      28
# 28  104.3  ...  3.78    3.15          NaN         114  5400   24      28
#
#     price engine-size compression
# 26  12940       141.0         9.5
# 27  13415       141.0         9.5
# 28  15985       141.0         9.5
#
# [3 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#FF4500"> 2.3 Análisis de imputación de valores números con la media. </h2>
# <img src="data.jpg" alt="Valores Perdidos">

# %%
mean_value = dfAutos["engine-size"].astype("float").mean(axis=0) #obteniendo la media de la variable
print("La media de engine-size es: ", mean_value)
# Out:
# La media de engine-size es:  128.0

# %%
dfAutos["horsepower"].replace(np.nan, 102, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price engine-size compression
# 0      27  13495       128.0        11.0
# 1      27  16500       128.0        11.0
# 2      26  16500       128.0        11.0
# 3      30  13950       128.0        11.0
# 4      22  17450       128.0        11.0
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#008080"> 2.4 Análisis de imputación de valores categóricos con el más frecuente. </h2>

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price engine-size compression
# 0      27  13495         NaN         NaN
# 1      27  16500         NaN         NaN
# 2      26  16500         NaN         NaN
# 3      30  13950         NaN         NaN
# 4      22  17450         NaN         NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#708090"> 2.5 Eliminar filas con valores faltantes. </h2>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace = True)
dfAutos.reset_index(drop = True, inplace = True)

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(10)

for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# Engine Size
# False    193
# True      29
# Name: Engine Size, dtype: int64
#
# system
# False    222
# Name: system, dtype: int64
#
# bore
# False    222
# Name: bore, dtype: int64
#
# stroke
# False    222
# Name: stroke, dtype: int64
#
# Compression
# False    222
# Name: Compression, dtype: int64
#
# horsepower
# False    222
# Name: horsepower, dtype: int64
#
# peak
# False    222
# Name: peak, dtype: int64
#
# City
# False    222
# Name: City, dtype: int64
#
# Higway
# False    222
# Name: Higway, dtype: int64
#
# price
# False    222
# Name: price, dtype: int64
#
# engine-size
# False    222
# Name: engine-size, dtype: int64
#
# compression
# False    222
# Name: compression, dtype: int64

# %% [markdown]
# <h2 style="color: 2082D8"> 3 Estandarización de los datos </h2>
#
# <p> ¿Qué se hace en este apartado? </p>
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en función de su interpretación </li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>
#
# <h3 style="color: #B22222">3.1 Verificacion del dominio de variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price engine-size compression
# 0      27  13495       128.0        11.0
# 1      27  16500       128.0        11.0
# 2      26  16500       128.0        11.0
# 3      30  13950       128.0        11.0
# 4      22  17450       128.0        11.0
#
# [5 rows x 28 columns]

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# Engine Size    float64
# system          object
# bore            object
# stroke          object
# Compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# engine-size    float64
# compression    float64
# dtype: object

# %%
dfAutos[["normalized"]] = dfAutos[["normalized"]].astype("int")
dfAutos[["bore", "stroke", "peak", "horsepower", "price"]] = dfAutos[["bore", "stroke", "peak", "horsepower", "price"]].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# Engine Size    float64
# system          object
# bore           float64
# stroke         float64
# Compression    float64
# horsepower     float64
# peak           float64
# City             int64
# Higway           int64
# price          float64
# engine-size    float64
# compression    float64
# dtype: object

# %% [markdown]
# <h3 style="color: #B22222">3.2 Estandarización de valores </h3>

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  bore  stroke  Compression  horsepower    peak  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
# 1    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
#
#   City  Higway    price  engine-size  compression
# 0   21      27  13495.0        128.0         11.0
# 1   21      27  16500.0        128.0         11.0
#
# [2 rows x 28 columns]

# %%
dfAutos["City Lts/100Km"] = 235/dfAutos["City"] #Conversión de consumo de combustible de galones p/ milla a Km por hora en ciudad
dfAutos["Higway Lts/100Km"] = 235/dfAutos["Higway"] #Conversión de consumo de combustible de galones p/ milla a Km por hora en autopista
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  Compression  horsepower    peak  City Higway  \
# 0    rwd  front  88.6  ...          9.0       111.0  5000.0    21     27
# 1    rwd  front  88.6  ...          9.0       111.0  5000.0    21     27
#
#      price  engine-size compression  City Lts/100Km  Higway Lts/100Km
# 0  13495.0        128.0        11.0       11.190476          8.703704
# 1  16500.0        128.0        11.0       11.190476          8.703704
#
# [2 rows x 30 columns]

# %% [markdown]
# <h3 style="color:#006400">3.3 Normalización de valores </h3>

# %%
dfTemp = dfAutos[["length", "width", "heingt"]]
dfTemp.head(5)
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
dfAutos["length"] = dfAutos["length"]/dfAutos["length"].max()
dfAutos["width"] = dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"] = dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dfTemp = dfAutos[["length", "width", "heingt"]]
dfTemp.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h3 style="color:#008B8B"> 3.3 Binning </h3>

# %%
dfTemp = dfAutos["horsepower"]
dfTemp.head(11)
# Out:
# 0     111.0
# 1     111.0
# 2     154.0
# 3     102.0
# 4     115.0
# 5     110.0
# 6     110.0
# 7     110.0
# 8     140.0
# 9     101.0
# 10    101.0
# Name: horsepower, dtype: float64

# %%
bins = np.linspace(min(dfAutos["horsepower"]),max(dfAutos["horsepower"]),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupNames = ["bajo", "medio", "alto"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"], bins, labels=groupNames, include_lowest=True)
dfAutos[["horsepower", "horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0       111.0           bajo
# 1       111.0           bajo
# 2       154.0          medio
# 3       102.0           bajo
# 4       115.0           bajo

# %%
dfAutos["horsepowerBins"].value_counts()
# Out:
# bajo     174
# medio     43
# alto       5
# Name: horsepowerBins, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(dfAutos["horsepower"])

plt.pyplot.title("HorsePower")
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("HorsePower")
# Out:
# Text(0, 0.5, 'HorsePower')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(dfAutos["horsepowerBins"])

plt.pyplot.title("HorsePower")
plt.pyplot.xlabel("Cantidad")
plt.pyplot.ylabel("HorsePower")
# Out:
# Text(0, 0.5, 'HorsePower')

# %%
dfAutos.tail()
# Out:
#      symboling  normalized        make    fuel aspiration doors  style wheels  \
# 217          0         122  volkswagen  diesel      turbo  four  sedan    fwd
# 218          0         122  volkswagen     gas        std  four  wagon    fwd
# 219         -2         103       volvo     gas        std  four  sedan    rwd
# 220         -1          74       volvo     gas        std  four  wagon    rwd
# 221         -2         103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  horsepower    peak  City  Higway    price engine-size  \
# 217  front  100.4  ...        68.0  4500.0    33      38  13845.0        97.0
# 218  front  100.4  ...        88.0  5500.0    25      31  12290.0       109.0
# 219  front  104.3  ...       114.0  5400.0    23      28  12940.0       141.0
# 220  front  104.3  ...       114.0  5400.0    23      28  13415.0       141.0
# 221  front  104.3  ...       114.0  5400.0    24      28  15985.0       141.0
#
#      compression City Lts/100Km  Higway Lts/100Km  horsepowerBins
# 217         23.0       7.121212          6.184211            bajo
# 218          9.0       9.400000          7.580645            bajo
# 219          9.5      10.217391          8.392857            bajo
# 220          9.5      10.217391          8.392857            bajo
# 221          9.5       9.791667          8.392857            bajo
#
# [5 rows x 31 columns]
